# %%
import pandas as pd
from utils import make_connection

# %%
db_conn = make_connection(config_file = 'db_config.ini')
db_cursor = db_conn.cursor()
# Out:
# Connection successful

# %%
wh_conn = make_connection(config_file = 'dw_config.ini')
wh_cursor = wh_conn.cursor()
# Out:
# Connection successful

# %% [markdown]
# **User_Dim**

# %%
# Fetching all_restaurants table data
all_users_data = 'Select * from users'

db_cursor.execute(all_users_data)

# %%
rows  = db_cursor.fetchall()
count = db_cursor.rowcount
print(count)
# Out:
# 503

# %%
# Creating dataframe of all_restaurants data
all_users_df = pd.DataFrame(rows)
all_users_df.head(3)
# Out:
#                     0                               1           2         3  \
# 0  Miss Maria Meza MD   christopherobrien@hotmail.com   688662959     Admin
# 1       Eileen Pierce    zgardner@alvarado-patton.com  1814255960     Admin
# 2    Kenneth Calderon  mckenziejerry@davis-garcia.com  9595904348  Customer
#
#    4           5
# 0  1  HS6+7RXrp6
# 1  2  T&gb5UeTcm
# 2  3  *6sD0y&is7

# %%
num_fields = len(db_cursor.description)
field_names = [i[0] for i in db_cursor.description]
field_names
# Out:
# ['Name', 'email', 'Phone', 'Role', 'User_ID', 'password']

# %%
all_users_df.columns = field_names
all_users_df.head()
# Out:
#                  Name                           email       Phone      Role  \
# 0  Miss Maria Meza MD   christopherobrien@hotmail.com   688662959     Admin
# 1       Eileen Pierce    zgardner@alvarado-patton.com  1814255960     Admin
# 2    Kenneth Calderon  mckenziejerry@davis-garcia.com  9595904348  Customer
# 3     Margaret Nelson      kristen38@hansen-smith.org   563094164  Customer
# 4         Lisa Willis      kennethmccoy@campbell.info  2190028180  Customer
#
#    User_ID    password
# 0        1  HS6+7RXrp6
# 1        2  T&gb5UeTcm
# 2        3  *6sD0y&is7
# 3        4  kR(82)Lfq$
# 4        5  de3SVPcom+

# %%
users_df = all_users_df[['User_ID', 'Name', 'email']]

# %%
for i, row in users_df.iterrows():
    sql = "INSERT INTO user_dim (user_id, name, email) VALUES (%s, %s, %s)"
    wh_cursor.execute(sql, tuple(row))

wh_conn.commit()

# %% [markdown]
# **Table_Dim**

# %%
# Fetching all_restaurants table data
all_tables_data = 'Select * from table_details'

db_cursor.execute(all_tables_data)

rows  = db_cursor.fetchall()
count = db_cursor.rowcount
print(count)
# Out:
# 20

# %%
# Creating dataframe of all_restaurants data
all_tables_df = pd.DataFrame(rows)

num_fields = len(db_cursor.description)
field_names = [i[0] for i in db_cursor.description]
field_names

all_tables_df.columns = field_names
all_tables_df.head()
# Out:
#    Table_ID  Seating_Capacity       Location
# 0         1                 2  Indoor Dining
# 1         2                 7  Indoor Dining
# 2         3                 3          Patio
# 3         4                 7          Patio
# 4         5                 7  Indoor Dining

# %%
tables_df = all_tables_df[['Table_ID', 'Seating_Capacity', 'Location']]

# %%
for i, row in tables_df.iterrows():
    sql = "INSERT INTO tables_dim (table_id, seating_capacity, location) VALUES (%s, %s, %s)"
    wh_cursor.execute(sql, tuple(row))

wh_conn.commit()

# %% [markdown]
# **Menu_Dim**

# %%
# Fetching all_restaurants table data
all_menu_data = '''
                SELECT  m.Menu_ID, m.Category, m.Item_Name, m.Price, ROUND(AVG(r.Rating),2) AS Rating
                FROM star_spartans_db2.menu m
                JOIN star_spartans_db2.review r on m.Menu_ID = r.Menu_ID
                GROUP BY m.Menu_ID;
                '''

db_cursor.execute(all_menu_data)

rows  = db_cursor.fetchall()
count = db_cursor.rowcount
print(count)
# Out:
# 50

# %%
# Creating dataframe of all_restaurants data
all_menu_df = pd.DataFrame(rows)

num_fields = len(db_cursor.description)
field_names = [i[0] for i in db_cursor.description]
field_names

all_menu_df.columns = field_names
all_menu_df.head()
# Out:
#    Menu_ID   Category                                      Item_Name  Price  \
# 0        1  Appetizer                                        Samosas   4.99
# 1        2  Appetizer                   Pakoras (vegetable fritters)   5.99
# 2        3  Appetizer                    Aloo Tikki (potato patties)   4.49
# 3        4  Appetizer  Chaat (varieties like papdi chaat, bhel puri)   6.99
# 4        5  Appetizer                                   Paneer Tikka   8.99
#
#   Rating
# 0   3.00
# 1   3.50
# 2   3.67
# 3   3.50
# 4   2.00

# %%
for i, row in all_menu_df.iterrows():
    sql = "INSERT INTO menu_dim (menu_id, category, item_name, price, rating) VALUES (%s, %s, %s, %s, %s)"
    wh_cursor.execute(sql, tuple(row))

wh_conn.commit()

# %% [markdown]
# **Date_Dim**

# %%
# Fetching all_restaurants table data
all_orders_data = 'Select * from orders'

db_cursor.execute(all_orders_data)

rows  = db_cursor.fetchall()
count = db_cursor.rowcount
print(count)
# Out:
# 501

# %%
# Creating dataframe of all_restaurants data
all_orders_df = pd.DataFrame(rows)

num_fields = len(db_cursor.description)
field_names = [i[0] for i in db_cursor.description]
field_names

all_orders_df.columns = field_names
all_orders_df.head()
# Out:
#    Order_ID  Day_Of_week  Month  Year  Date  Order_Time  User_ID
# 0         1            5      4  2022    22          14       32
# 1         2            6      2  2022    12          12      198
# 2         3            3     10  2022    26          19      204
# 3         4            2      2  2022     1           4      447
# 4         5            3      3  2022    16           2      347

# %%
orders_df = all_orders_df[['Date', 'Month', 'Year', 'Day_Of_week']]
orders_df = orders_df.rename(columns={'Day_Of_week': 'Day_Of_Week'})
orders_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 501 entries, 0 to 500
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Date         501 non-null    int64
#  1   Month        501 non-null    int64
#  2   Year         501 non-null    int64
#  3   Day_Of_Week  501 non-null    int64
# dtypes: int64(4)
# memory usage: 15.8 KB

# %% [markdown]
# Inserting reservation dates now

# %%
# Fetching all_restaurants table data
all_reservations_data = 'Select * from reservation'

db_cursor.execute(all_reservations_data)

rows  = db_cursor.fetchall()
count = db_cursor.rowcount
print(count)
# Out:
# 52

# %%
# Creating dataframe of all_restaurants data
all_reservations_df = pd.DataFrame(rows)

num_fields = len(db_cursor.description)
field_names = [i[0] for i in db_cursor.description]
field_names

all_reservations_df.columns = field_names
all_reservations_df.head()
# Out:
#    Reservation_ID  Day_Of_Week        date  Reservation_Time  \
# 0               1            5  2023-02-20                16
# 1               2            2  2023-02-09                13
# 2               3            1  2023-06-02                15
# 3               4            5  2023-11-28                11
# 4               5            5  2023-01-31                13
#
#    Number_of_Guests  User_ID  Table_ID
# 0                 5      396         2
# 1                 1      395        14
# 2                 8      365        20
# 3                 6      354         5
# 4                 2      482         8

# %%
reservations_df = all_reservations_df[['date', 'Day_Of_Week']]
reservations_df.head()
# Out:
#          date  Day_Of_Week
# 0  2023-02-20            5
# 1  2023-02-09            2
# 2  2023-06-02            1
# 3  2023-11-28            5
# 4  2023-01-31            5

# %%
reservations_df['date'] = pd.to_datetime(reservations_df['date'])

# Extract year, month, and day
reservations_df['Year'] = reservations_df['date'].dt.year
reservations_df['Month'] = reservations_df['date'].dt.month
reservations_df['Date'] = reservations_df['date'].dt.day

reservations_df.head()
# Out:
# C:\Users\Parth\AppData\Local\Temp\ipykernel_9176\2970548479.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   reservations_df['date'] = pd.to_datetime(reservations_df['date'])
# C:\Users\Parth\AppData\Local\Temp\ipykernel_9176\2970548479.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   reservations_df['Year'] = reservations_df['date'].dt.year
# C:\Users\Parth\AppData\Local\Temp\ipykernel_9176\2970548479.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   reservations_df['Month'] = reservations_df['date'].dt.month
# C:\Users\Parth\AppData\Local\Temp\ipykernel_9176\2970548479.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   reservations_df['Date'] = reservations_df['date'].dt.day
#         date  Day_Of_Week  Year  Month  Date
# 0 2023-02-20            5  2023      2    20
# 1 2023-02-09            2  2023      2     9
# 2 2023-06-02            1  2023      6     2
# 3 2023-11-28            5  2023     11    28
# 4 2023-01-31            5  2023      1    31

# %%
cleaned_reservations_df = reservations_df[['Date', 'Month', 'Year', 'Day_Of_Week']]
cleaned_reservations_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52 entries, 0 to 51
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Date         52 non-null     int64
#  1   Month        52 non-null     int64
#  2   Year         52 non-null     int64
#  3   Day_Of_Week  52 non-null     int64
# dtypes: int64(4)
# memory usage: 1.8 KB

# %%
# Concatenate the two DataFrames
combined_order_reservation_date_df = pd.concat([orders_df, cleaned_reservations_df])

# %%
combined_order_reservation_date_df.head()
# Out:
#    Date  Month  Year  Day_Of_Week
# 0    22      4  2022            5
# 1    12      2  2022            6
# 2    26     10  2022            3
# 3     1      2  2022            2
# 4    16      3  2022            3

# %%
combined_order_reservation_date_df = combined_order_reservation_date_df.drop_duplicates(subset=['Date', 'Month', 'Year'])

# %%
for i, row in combined_order_reservation_date_df.iterrows():
    sql = "INSERT INTO date_dim (day, month, year, dow) VALUES (%s, %s, %s, %s)"
    wh_cursor.execute(sql, tuple(row))

wh_conn.commit()

# %% [markdown]
# **Reservation_Fact**

# %%
all_reservations_df.head()
# Out:
#    Reservation_ID  Day_Of_Week        date  Reservation_Time  \
# 0               1            5  2023-02-20                16
# 1               2            2  2023-02-09                13
# 2               3            1  2023-06-02                15
# 3               4            5  2023-11-28                11
# 4               5            5  2023-01-31                13
#
#    Number_of_Guests  User_ID  Table_ID
# 0                 5      396         2
# 1                 1      395        14
# 2                 8      365        20
# 3                 6      354         5
# 4                 2      482         8

# %%
reservations_fact_df = all_reservations_df[['Reservation_ID', 'Number_of_Guests', 'Reservation_Time', 'date', 'Table_ID', 'User_ID',]]
reservations_fact_df.head()
# Out:
#    Reservation_ID  Number_of_Guests  Reservation_Time        date  Table_ID  \
# 0               1                 5                16  2023-02-20         2
# 1               2                 1                13  2023-02-09        14
# 2               3                 8                15  2023-06-02        20
# 3               4                 6                11  2023-11-28         5
# 4               5                 2                13  2023-01-31         8
#
#    User_ID
# 0      396
# 1      395
# 2      365
# 3      354
# 4      482

# %%
reservations_fact_df['date'] = pd.to_datetime(reservations_fact_df['date'])

# Extract year, month, and day
reservations_fact_df['date_id_year'] = reservations_fact_df['date'].dt.year
reservations_fact_df['date_id_month'] = reservations_fact_df['date'].dt.month
reservations_fact_df['date_id_day'] = reservations_fact_df['date'].dt.day

reservations_fact_df.head()
# Out:
# C:\Users\Parth\AppData\Local\Temp\ipykernel_9176\4107132059.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   reservations_fact_df['date'] = pd.to_datetime(reservations_fact_df['date'])
#    Reservation_ID  Number_of_Guests  Reservation_Time       date  Table_ID  \
# 0               1                 5                16 2023-02-20         2
# 1               2                 1                13 2023-02-09        14
# 2               3                 8                15 2023-06-02        20
# 3               4                 6                11 2023-11-28         5
# 4               5                 2                13 2023-01-31         8
#
#    User_ID  date_id_year  date_id_month  date_id_day
# 0      396          2023              2           20
# 1      395          2023              2            9
# 2      365          2023              6            2
# 3      354          2023             11           28
# 4      482          2023              1           31

# %%
cleaned_reservations_fact_df = reservations_fact_df[['Reservation_ID', 'Number_of_Guests', 'Reservation_Time', 'date_id_day', 'date_id_month', 'date_id_year', 'Table_ID', 'User_ID',]]

cleaned_reservations_fact_df.head()
# Out:
#    Reservation_ID  Number_of_Guests  Reservation_Time  date_id_day  \
# 0               1                 5                16           20
# 1               2                 1                13            9
# 2               3                 8                15            2
# 3               4                 6                11           28
# 4               5                 2                13           31
#
#    date_id_month  date_id_year  Table_ID  User_ID
# 0              2          2023         2      396
# 1              2          2023        14      395
# 2              6          2023        20      365
# 3             11          2023         5      354
# 4              1          2023         8      482

# %%
for i, row in cleaned_reservations_fact_df.iterrows():
    sql = '''
            INSERT INTO reservation_fact (reservation_id, no_of_guest, time, date_id_day, date_id_month, date_id_year, table_id, user_id) 
            VALUES (%s, %s, %s, %s, %s, %s, %s, %s)
        '''
    wh_cursor.execute(sql, tuple(row))

wh_conn.commit()

# %% [markdown]
# **Sales_Fact**

# %%
all_orders_df.head()
# Out:
#    Order_ID  Day_Of_week  Month  Year  Date  Order_Time  User_ID
# 0         1            5      4  2022    22          14       32
# 1         2            6      2  2022    12          12      198
# 2         3            3     10  2022    26          19      204
# 3         4            2      2  2022     1           4      447
# 4         5            3      3  2022    16           2      347

# %%
# Fetching all_restaurants table data
all_order_details_data = 'Select * from order_details'

db_cursor.execute(all_order_details_data)

rows  = db_cursor.fetchall()
count = db_cursor.rowcount
print(count)
# Out:
# 1002

# %%
# Creating dataframe of all_restaurants data
all_order_details_df = pd.DataFrame(rows)

num_fields = len(db_cursor.description)
field_names = [i[0] for i in db_cursor.description]
field_names

all_order_details_df.columns = field_names
all_order_details_df.head()
# Out:
#    Order_Details_ID  Unit_Price  Quantity  Menu_ID  Order_ID
# 0                 1        7.99         3       16         8
# 1                 2       13.99         3       16       389
# 2                 3       12.99         1       14       269
# 3                 4        4.99         7       29        46
# 4                 5        7.99         1       28       469

# %%
# Assuming all_orders_df and all_order_details_df are your DataFrames
merged_order_details_df = all_orders_df.merge(all_order_details_df, on='Order_ID', how='inner')
merged_order_details_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1002 entries, 0 to 1001
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Order_ID          1002 non-null   int64
#  1   Day_Of_week       1002 non-null   int64
#  2   Month             1002 non-null   int64
#  3   Year              1002 non-null   int64
#  4   Date              1002 non-null   int64
#  5   Order_Time        1002 non-null   int64
#  6   User_ID           1002 non-null   int64
#  7   Order_Details_ID  1002 non-null   int64
#  8   Unit_Price        1002 non-null   float64
#  9   Quantity          1002 non-null   int64
#  10  Menu_ID           1002 non-null   int64
# dtypes: float64(1), int64(10)
# memory usage: 93.9 KB

# %%
merged_order_details_df['total_sale_amount'] = merged_order_details_df['Unit_Price'] * merged_order_details_df['Quantity']

# %%
merged_order_details_df.head()
# Out:
#    Order_ID  Day_Of_week  Month  Year  Date  Order_Time  User_ID  \
# 0         1            5      4  2022    22          14       32
# 1         1            5      4  2022    22          14       32
# 2         1            5      4  2022    22          14       32
# 3         2            6      2  2022    12          12      198
# 4         3            3     10  2022    26          19      204
#
#    Order_Details_ID  Unit_Price  Quantity  Menu_ID  total_sale_amount
# 0               235        7.99         2       43              15.98
# 1               531       10.99         5       45              54.95
# 2               949        7.99         7       29              55.93
# 3               256        7.49         2       39              14.98
# 4               126        6.99         7       48              48.93

# %%
# Convert to string and pad
merged_order_details_df['Order_ID'] = merged_order_details_df['Order_ID'].astype(str).str.zfill(5)
merged_order_details_df['Order_Details_ID'] = merged_order_details_df['Order_Details_ID'].astype(str).str.zfill(5)

merged_order_details_df.head()
# Out:
#   Order_ID  Day_Of_week  Month  Year  Date  Order_Time  User_ID  \
# 0    00001            5      4  2022    22          14       32
# 1    00001            5      4  2022    22          14       32
# 2    00001            5      4  2022    22          14       32
# 3    00002            6      2  2022    12          12      198
# 4    00003            3     10  2022    26          19      204
#
#   Order_Details_ID  Unit_Price  Quantity  Menu_ID  total_sale_amount
# 0            00235        7.99         2       43              15.98
# 1            00531       10.99         5       45              54.95
# 2            00949        7.99         7       29              55.93
# 3            00256        7.49         2       39              14.98
# 4            00126        6.99         7       48              48.93

# %%
cleaned_sales_fact_df = merged_order_details_df[['Quantity', 'total_sale_amount', 'Order_ID', 'Order_Details_ID', 'Menu_ID', 'User_ID', 'Date', 'Month', 'Year']]

cleaned_sales_fact_df.head()
# Out:
#    Quantity  total_sale_amount Order_ID Order_Details_ID  Menu_ID  User_ID  \
# 0         2              15.98    00001            00235       43       32
# 1         5              54.95    00001            00531       45       32
# 2         7              55.93    00001            00949       29       32
# 3         2              14.98    00002            00256       39      198
# 4         7              48.93    00003            00126       48      204
#
#    Date  Month  Year
# 0    22      4  2022
# 1    22      4  2022
# 2    22      4  2022
# 3    12      2  2022
# 4    26     10  2022

# %%
for i, row in cleaned_sales_fact_df.iterrows():
    sql = '''
            INSERT INTO sales_fact (quantity, total_sale_amount, order_id, order_details_id, menu_id, user_id, date_id_day, date_id_month, date_id_year) 
            VALUES (%s, %s, %s, %s, %s, %s, %s, %s, %s)
        '''
    wh_cursor.execute(sql, tuple(row))

wh_conn.commit()

# %%
wh_cursor.close()
wh_conn.close()

# %%
db_cursor.close()
db_conn.close()
